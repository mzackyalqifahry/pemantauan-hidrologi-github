# %% [markdown]
# <a href="https://colab.research.google.com/github/mzackyalqifahry/pemantauan-hidrologi-github/blob/main/SOAL3_Convolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

fs = 100  # frekuensi sampling
f = 10    # frekuensi sinyal input
n = np.arange(0, 50)

# Sinyal input diskrit x[n] = 2cos(2𝜔𝑡)
x = 2 * np.cos(2 * np.pi * f * n / fs)

# Sinyal impuls h[n]
h = np.array([1, 2, 1, 0, -9, 1, 2, 1, 1, 1, 0, 5])

# Convolution  diskrit
y = np.convolve(x, h)
plt.figure(figsize=(10, 6))

plt.subplot(3, 1, 1)
plt.stem(n, x)
plt.title('Input Signal x[n] = 2cos(2π·10n/fs)')
plt.ylabel('Amplitude')
plt.grid(True)

plt.subplot(3, 1, 2)
plt.stem(np.arange(len(h)), h)
plt.title('Impulse Response h[n]')
plt.ylabel('Amplitude')
plt.grid(True)

plt.subplot(3, 1, 3)
plt.stem(np.arange(len(y)), y)
plt.title('Output Signal y[n] = x[n] * h[n]')
plt.xlabel('n (samples)')
plt.ylabel('Amplitude')
plt.grid(e)

plt.tight_layout()
plt.show()
